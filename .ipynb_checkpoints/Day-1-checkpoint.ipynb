# %%
#The Basics of Python: 
"Hello World!"
# Out:
# 'Hello World!'

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 123
print("a")
# Out:
# a

# %%
print(a)
# Out:
# 123

# %%
def recSum(n):
    if(n==1):
        return 1;

    return n+recSum(n-1)

recSum(11)
# Out:
# 66

# %%
def mathSum(n):
    return int(n*(n+1)/2)

# %%
mathSum(10)
# Out:
# 55

# %%
c = 5 + 2j
print(c.real, type(c.real))
print(c.imag,type (c.imag))
# Out:
# 5.0 <class 'float'>
# 2.0 <class 'float'>

# %%
l = [1,2,3,4,5]
m = l[::-1]
print(m)
# Out:
# [5, 4, 3, 2, 1]

# %%
m.append(0)
m
# Out:
# [5, 4, 3, 2, 1, 0]

# %%
l.append(6)

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
m
# Out:
# [5, 4, 3, 2, 1, 0]

# %%
q = [1,2,3,4,5]
r = q

# %%
q.append(6)

# %%
r
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
t = (1,2,3,4)
print(type(t))
# Out:
# <class 'tuple'>

# %%
t
# Out:
# (1, 2, 3, 4)

# %%
t1 = (4,5,6)
print(t+t1)
# Out:
# (1, 2, 3, 4, 4, 5, 6)

# %%
t.append(t1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 t.append(t1)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
dict = {'a': 1,'b':2,'c':3}
print(dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
print(type(dict))
# Out:
# <class 'dict'>

# %%
dict1 = {'Rutik':1000,'Pranav J':1001}

# %%
type(dict1)
# Out:
# dict

# %%
print(dict1)
# Out:
# {'Rutik': 1000, 'Pranav J': 1001}

# %%
s = 'bhopal'
print(s+'42')
# Out:
# bhopal42

# %%
print("test {}".format(42))
# Out:
# test 42

# %%
print(type("test {}".format(42)))
# Out:
# <class 'str'>

# %%
#Nested Condition

statement = True
statement1 = False

if statement:
    if statement1:
        print("both statements are executed")
    else:
        print("Only Statement 1 is executed")
# Out:
# Only Statement 1 is executed

# %%
jm = ""
for word in ["Python","For","Data","Science"]:
    print(jm+" "+word)
# Out:
#  Python
#  For
#  Data
#  Science

# %%
a = [10,20,30]
b = 0

try:
    a[4] = 2 
    print(a)
except Exception as e:
    print(e)
# Out:
# list assignment index out of range

# %%
print("run from the sun like dracula")
# Out:
# run from the sun like dracula
